# %%
import torch
import torchaudio
torchaudio.set_audio_backend("sox_io") #If i didn't add this part it would send me a warning that i needed it
from matplotlib import pyplot as plt
import os
from torch.utils.data import Dataset, DataLoader
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/torchaudio/backend/utils.py:54: UserWarning: "sox" backend is being deprecated. The default backend will be changed to "sox_io" backend in 0.8.0 and "sox" backend will be removed in 0.9.0. Please migrate to "sox_io" backend. Please refer to https://github.com/pytorch/audio/issues/903 for the detail.
#   '"sox" backend is being deprecated. '

# %%
path='sacco/audio_24@10-01-2020_18-39-11.ogg'
audio_signal,sample_rate=torchaudio.load(path)
print(type(audio_signal))
Spectrogram=torchaudio.transforms.Spectrogram() #Define the function of the spectogram
spectogram=Spectrogram(audio_signal) #calculate the spectogram
spectogram=torch.load('sacco_spectrograms/audio_25@10-01-2020_18-40-14.pt')
plt.imshow(spectogram.log2()[0,:,800:1600]) #To see the images you have to use the log2
plt.show()
# Out:
# <class 'torch.Tensor'>

# %% [markdown]
# # Data loader

# %%
#Do i have to add cuda here?
class Data(Dataset):
    def __init__(self,peaple,audio=None,authors=None):
        if audio==None: self.audio=[]
        else: self.audio=audio
        if authors==None: self.authors=[]
        else: self.authors=authors
        self.peaple=peaple       
        
    
    def __len__(self):
        return len(self.audio)
    
    #Does not work if you call Data[x:y]    
    def __getitem__(self,index):
        if torch.is_tensor(index):
            index = idx.tolist()
            
        audio=self.audio[index]
        authors=self.authors[index]

        return audio,authors 
    
    def append(audio,authors):
        self.audio.append(audio)
        self.authors.append(authors)

# %%
directories=['sacco_spectrograms/','ischia_spectrograms/','tiziano_spectrograms/']
peaple=['sacco','ischia','tiziano']

dataset=Data(peaple)

for directory,author in zip(directories,peaple):
    for file in os.listdir(directory):
        print(directory+file)
        temp=torch.zeros(len(peaple))
        temp[peaple.index(author)]=1
        tens=torch.load(directory+file)
        dataset.append(tens,temp)
        break
    break
# Out:
# sacco_spectrograms/audio_25@10-01-2020_18-40-14.pt
# tensor([1.4588e+00, 8.2460e-01, 1.7084e-01,  ..., 2.3736e-05, 7.7117e-02,
#         1.4001e-01])
# ---------------------------------------------------------------------
# TypeError                           Traceback (most recent call last)
# <ipython-input-22-0808208a0ce9> in <module>
#      11         tens=torch.load(directory+file)
#      12         print(tens[0,0])
# ---> 13         dataset.append(tens[0],temp)
#      14         break
#      15     break
#
# TypeError: append() takes 2 positional arguments but 3 were given

# %%
dataset.transform_audio=None
train=DataLoader(dataset,2,collate_fn=lambda x: x)  #non so che faccia collate_fn ma almeno così non mi da errore

# %%
authors=authors[:50]
if type(authors)==type('str'):
    N=peaple.index(authors)
    authors=torch.zeros(len(peaple))
    authors[N]=1
else:
    lung=len(authors)
    N=[peaple.index(i) for i in authors]
    authors=torch.zeros(lung,len(peaple))
    for i in range(lung):
        authors[i,N[i]]=1

#print(authors)
# Out:
# ---------------------------------------------------------------------
# ValueError                          Traceback (most recent call last)
# <ipython-input-25-811184957718> in <module>
#       6 else:
#       7     lung=len(authors)
# ----> 8     N=[peaple.index(i) for i in authors]
#       9     authors=torch.zeros(lung,len(peaple))
#      10     for i in range(lung):
#
# <ipython-input-25-811184957718> in <listcomp>(.0)
#       6 else:
#       7     lung=len(authors)
# ----> 8     N=[peaple.index(i) for i in authors]
#       9     authors=torch.zeros(lung,len(peaple))
#      10     for i in range(lung):
#
# ValueError: tensor([1., 0., 0.]) is not in list

# %% [markdown]
# # The Algorithm
# in this first part we will be training an adversarial net that will be able to recognise the voice from a person from a voice syntecyzed from noise, so we will need two nets:
# - Noise to signal
# - Discriminator
#
# Let's start from the first one

# %% [markdown]
# ### Noise to signal
# it will be a Recursive Neural Network (RNN) that takes noise (or audio from another person) as inputs and outputs a syntesized audio

# %%
#Add hyperparameters
class Noise_to_Signal(nn.Module):#WIP
    def __init__(self):
        super(Noise_to_Signal, self).__init__()
        
        
    def forward(self,x):

# %% [markdown]
# ### Discriminator
# it will be a RNN a audio signal as input and decides if it is from the subject or if it's artificial

# %%
#Add hyperparameters
class Discriminator(nn.Module):#WIP
    def __init__(self):
        super(Discriminator, self).__init__()
        
        
    def forward(self,x):
