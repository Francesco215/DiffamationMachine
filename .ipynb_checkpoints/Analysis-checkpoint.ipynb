# %%
import torch
import torchaudio
torchaudio.set_audio_backend("sox_io") #If i didn't add this part it would send me a warning that i needed it
from matplotlib import pyplot as plt

# %%
path='sacco/audio_1@05-03-2020_15-42-02.ogg'
audio_signal,sample_rate=torchaudio.load(path)
print(type(audio_signal))
# Out:
# <class 'torch.Tensor'>

# %%
Spectrogram=torchaudio.transforms.Spectrogram() #Define the function of the spectogram
spectogram=Spectrogram(audio_signal) #calculate the spectogram
print(spectogram.shape)
plt.imshow(spectogram.log2()[0,:,800:1600]) #To see the images you have to use the log2
plt.show()
# Out:
# torch.Size([1, 201, 20793])

# %% [markdown]
# # Data loader

# %%
import os
from torch.utils.data import Dataset, DataLoader

# %%
#Do i have to add cuda here?
class Data(Dataset):    
    def __init__(self,files,authors,peaple,transform_audio='spectogram',transform_author='tensor'):
        self.audio=files
        self.author=authors
        
        if transform_audio=='spectogram':
            self.transform_audio=torchaudio.transforms.Spectrogram()
        else:
            self.transform_audio=None        
        self.transform_author=transform_author
        
    
    def __len__(self):
        return len(self.author)
    
    #Does not work if you call Data[x:y]    
    def __getitem__(self,index):        
        if torch.is_tensor(index):
            index = idx.tolist()
            
        audio=self.audio[index]
        author=self.author[index]
        
        if self.transform_author=='tensor':
            N=Peaple.index(author)
            author=torch.zeros(len(Peaple))
            author[N]=1        
        if self.transform_audio:
            audio,munnizza=torchaudio.load(audio)
            audio=self.transform_audio(audio)
        
        return audio,author

# %%
directories=['sacco/','ischia_sacco/','tiziano_sacco/']
peaple=['sacco','ischia','tiziano']#Don't change the name
files=[]
authors=[]

for directory,author in zip(directories,Peaple):
    for file in os.listdir(directory):
        files.append(directory+file)
        authors.append(author)

dataset=Data(file,authors,peaple)

print(dataset[1:4])
# Out:
# ---------------------------------------------------------------------
# ValueError                          Traceback (most recent call last)
# <ipython-input-45-b4dbb9022f08> in <module>
#      11 dataset=Data(file,authors,peaple)
#      12
# ---> 13 print(dataset[1:4])
#
# <ipython-input-43-3d1ba3d44dce> in __getitem__(self, index)
#      24
#      25         if self.transform_author=='tensor':
# ---> 26             N=Peaple.index(author)
#      27             author=torch.zeros(len(Peaple))
#      28             author[N]=1
#
# ValueError: ['sacco', 'sacco', 'sacco'] is not in list

# %% [markdown]
# # The Algorithm
# in this first part we will be training an adversarial net that will be able to recognise the voice from a person from a voice syntecyzed from noise
#
# Now the nets are:

# %% [markdown]
# ### Noise to signal
# it will be a Recursive Neural Network (RNN) that takes noise (or audio from another person) as inputs and outputs a syntesized audio

# %%
#Add hyperparameters
class Noise_to_Signal(nn.Module):#WIP
    def __init__(self):
        super(Noise_to_Signal, self).__init__()
        
        
    def forward(self,x):

# %% [markdown]
# ### Discriminator
# it will be a RNN a audio signal as input and decides if it is from the subject or if it's artificial

# %%
#Add hyperparameters
class Discriminator(nn.Module):#WIP
    def __init__(self):
        super(Discriminator, self).__init__()
        
        
    def forward(self,x):
